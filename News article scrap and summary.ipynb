# %%
pip install nltk

# %%
pip install newspaper3k
# Out:
# ...
#      |████████████████████████████████| 215kB 2.6MB/s
# ...
#      |████████████████████████████████| 194kB 4.2MB/s
# ...
#      |████████████████████████████████| 7.4MB 5.4MB/s
# ...
#      |████████████████████████████████| 51kB 6.9MB/s
# ...
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-cp36-none-any.whl size=13539 sha256=fd93659ba292e5f4f2a9dc3b604bea29306db09b07d6d441631b8bf0acdd6efa
#   Stored in directory: /root/.cache/pip/wheels/81/2b/43/a02ede72324dd40cdd7ca53aad718c7710628e91b8b0dc0f02
# ...
#   Created wheel for feedparser: filename=feedparser-5.2.1-cp36-none-any.whl size=44940 sha256=beb4fbef80709d57d91d3521a75b65f906237ca261cff1347e5feb11d6fb42af
#   Stored in directory: /root/.cache/pip/wheels/8c/69/b7/f52763c41c5471df57703a0ef718a32a5e81ee35dcf6d4f97f
# ...
#   Created wheel for jieba3k: filename=jieba3k-0.35.1-cp36-none-any.whl size=7398406 sha256=b833e02e98f4a6319f7ecdc24f041e0423c9c05e5553eb16a3e9e95100dd3dbe
# ...

# %%
import nltk
from newspaper import Article

# %%
url = 'https://towardsdatascience.com/using-data-science-to-study-economic-inequality-in-the-united-states-1101e9350c3d'
article = Article(url)

# %%
article.download()
article.parse()
nltk.download('punkt')
article.nlp()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
article.authors
# Out:
# ['Andrew Hong']

# %%
article.publish_date
# Out:
# datetime.datetime(2020, 6, 22, 15, 24, 28, 162000, tzinfo=tzlocal())

# %%
article.top_image
# Out:
# 'https://miro.medium.com/max/1200/1*jS-t8J9OHf8FVZDF5Mj4Kw.jpeg'

# %%
print(article.text)

# %%
print(article.summary)
# Out:
# Data JournalismUsing Data Science to Study Economic Inequality in the United StatesHow can we use public data to analyze and understand the challenges Black communities face in the US?
# School District data is good because it gives insight on both children and their parents together.
# You can find Tunica County School District here, and search for others.
# I started collecting data on the largest 100 school districts in the United Sates as well as our six county school districts using bs4 and Selenium.
# On the interactive version, you can mouse over the dots to see the school district names.
